# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a dictionary to hold the data
data = {
    'Lesson': ['English Language 2', 'Physics 2', 'Discrete Mathematics', 'Electric and Electronic Circuits', 'Database Design', 'andishe 1', 'zaban omomi', 'tarbiat badani 2', 'zaban farsi', 'riazi omomi 2', 'mabani computer', 'moadelat difransiel', 'zaban takhasosi', 'kargah omomi', 'madar haye elektriki', 'moadelat', 'az fizik 2', 'amar o ehtemal', 'jabr khati', 'madar manteghi', 'memari computer', 'signals and systems', 'mohandesi narmafzar', 'system haye amel', 'ravesh haye pazhohesh'],
    'Semester_Passed': ['Even', 'Odd', 'Even', 'Even', 'Odd', 'Odd','Odd','Even','Even','Odd','Odd','Odd','Even','Even','Even','Even','Odd','Odd','Odd','Odd','Even','Even','Odd','Odd','Even'],
    'ECTS': [2, 3, 3, 3, 3, 2, 3, 1, 3, 3, 3, 3, 3, 1, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3],
    'Specialized_or_General_or_Basic': ['General', 'General', 'Basic', 'Specialized', 'Specialized', 'General', 'General', 'General', 'General', 'General', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized' ],
    'Instructor': ['Hajari', 'Salimi', 'Ahmadi', 'Mohammadi', 'Bidki', 'sajadi', 'Hajari', 'fotohi', 'Salimi', 'motlagh', 'ranjbar', 'motlagh', 'mahmoodi', 'ranjbar', 'mahmoodi', 'sotoodeh', 'safi nia', 'motlagh', 'joozi', 'bidki', 'ahmadi', 'mohammadi', 'ahmadi', 'ahmadi', 'ranjbar'],
    'Total_ECTS_in_Semester': [14, 17, 20, 14, 20, 5, 5, 14, 14, 17, 17, 17, 20, 20, 20, 20, 16, 16, 16, 16, 14, 14, 20, 20, 20],
    'Days_for_Final_Test': [2, 1, 1, 2, 0, 1, 0, 0, 2, 2, 2, 1, 4, 1, 0, 2, 0, 2, 2, 1, 0, 1, 2, 2, 2],
    'Nth_Test_of_Semester': [3, 2, 3, 3, 1, 2, 1, 0, 3, 2, 3, 4, 2, 3, 1, 4, 1, 2, 3, 4, 1, 2, 2, 3, 3],
    'Homework': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'],
    'Quiz': ['No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'],
    'Passed': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'],
    'Conditionally_Passed': ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No'],
    'Grade': ['A', 'A', 'A', 'A', 'B', 'A', 'B', 'A', 'A', 'C', 'B', 'C', 'A', 'B', 'C', 'B', 'B', 'C', 'B', 'C', 'A', 'B', 'B', 'B', 'A']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#                               Lesson Semester_Passed  ECTS  \
# 0                 English Language 2            Even     2
# 1                          Physics 2             Odd     3
# 2               Discrete Mathematics            Even     3
# 3   Electric and Electronic Circuits            Even     3
# 4                    Database Design             Odd     3
# 5                          andishe 1             Odd     2
# 6                        zaban omomi             Odd     3
# 7                   tarbiat badani 2            Even     1
# 8                        zaban farsi            Even     3
# 9                      riazi omomi 2             Odd     3
# 10                   mabani computer             Odd     3
# 11               moadelat difransiel             Odd     3
# 12                   zaban takhasosi            Even     3
# 13                      kargah omomi            Even     1
# 14              madar haye elektriki            Even     3
# 15                          moadelat            Even     3
# 16                        az fizik 2             Odd     1
# 17                    amar o ehtemal             Odd     3
# 18                        jabr khati             Odd     3
# 19                    madar manteghi             Odd     3
# 20                   memari computer            Even     3
# 21               signals and systems            Even     3
# 22               mohandesi narmafzar             Odd     3
# 23                  system haye amel             Odd     3
# 24             ravesh haye pazhohesh            Even     3
#
#    Specialized_or_General_or_Basic Instructor  Total_ECTS_in_Semester  \
# 0                          General     Hajari                      14
# 1                          General     Salimi                      17
# 2                            Basic     Ahmadi                      20
# 3                      Specialized  Mohammadi                      14
# 4                      Specialized      Bidki                      20
# 5                          General     sajadi                       5
# 6                          General     Hajari                       5
# 7                          General     fotohi                      14
# 8                          General     Salimi                      14
# 9                          General    motlagh                      17
# 10                     Specialized    ranjbar                      17
# 11                     Specialized    motlagh                      17
# 12                     Specialized   mahmoodi                      20
# 13                     Specialized    ranjbar                      20
# 14                     Specialized   mahmoodi                      20
# 15                     Specialized   sotoodeh                      20
# 16                     Specialized   safi nia                      16
# 17                     Specialized    motlagh                      16
# 18                     Specialized      joozi                      16
# 19                     Specialized      bidki                      16
# 20                     Specialized     ahmadi                      14
# 21                     Specialized  mohammadi                      14
# 22                     Specialized     ahmadi                      20
# 23                     Specialized     ahmadi                      20
# 24                     Specialized    ranjbar                      20
#
#     Days_for_Final_Test  Nth_Test_of_Semester Homework Quiz Passed  \
# 0                     2                     3      Yes   No    Yes
# 1                     1                     2      Yes  Yes    Yes
# 2                     1                     3      Yes  Yes    Yes
# 3                     2                     3      Yes  Yes    Yes
# 4                     0                     1      Yes  Yes    Yes
# 5                     1                     2       No   No    Yes
# 6                     0                     1      Yes  Yes    Yes
# 7                     0                     0       No   No    Yes
# 8                     2                     3       No   No    Yes
# 9                     2                     2      Yes  Yes    Yes
# 10                    2                     3      Yes  Yes    Yes
# 11                    1                     4      Yes  Yes     No
# 12                    4                     2      Yes   No    Yes
# 13                    1                     3      Yes  Yes    Yes
# 14                    0                     1      Yes  Yes     No
# 15                    2                     4      Yes  Yes    Yes
# 16                    0                     1      Yes  Yes    Yes
# 17                    2                     2      Yes  Yes    Yes
# 18                    2                     3      Yes  Yes    Yes
# 19                    1                     4      Yes  Yes    Yes
# 20                    0                     1      Yes  Yes    Yes
# 21                    1                     2      Yes  Yes    Yes
# 22                    2                     2      Yes  Yes    Yes
# 23                    2                     3      Yes  Yes    Yes
# 24                    2                     3      Yes  Yes    Yes
#
#    Conditionally_Passed Grade
# 0                    No     A
# 1                    No     A
# 2                    No     A
# 3                    No     A
# 4                    No     B
# 5                    No     A
# 6                    No     B
# 7                    No     A
# 8                    No     A
# 9                    No     C
# 10                   No     B
# 11                   No     C
# 12                   No     A
# 13                   No     B
# 14                   No     C
# 15                   No     B
# 16                   No     B
# 17                  Yes     C
# 18                  Yes     B
# 19                  Yes     C
# 20                   No     A
# 21                   No     B
# 22                   No     B
# 23                   No     B
# 24                   No     A

# %%
# Extract numeric attributes
numeric_attributes = ['ECTS', 'Total_ECTS_in_Semester', 'Days_for_Final_Test', 'Nth_Test_of_Semester']

# Create box plots for each numeric attribute
for attribute in numeric_attributes:
    plt.figure(figsize=(8, 6))
    plt.boxplot(data[attribute])
    plt.title(f'Box Plot of {attribute}')
    plt.ylabel('Value')
    plt.show()

# %%
# Given num_Grade values
num_Grade_values = ['19.83', '17.50', '17.10', '16', '12.50', '17.50', '15', '20', '19', '10', '12.94', '9', '20', '13', '9.9', '13.60', '15', '10', '15', '10', '16.20', '13.50', '15', '11.65', '19.33']

# Add num_Grade to the data dictionary
data['num_Grade'] = num_Grade_values

# Display the updated data with the new column
print(data)
# Out:
# {'Lesson': ['English Language 2', 'Physics 2', 'Discrete Mathematics', 'Electric and Electronic Circuits', 'Database Design', 'andishe 1', 'zaban omomi', 'tarbiat badani 2', 'zaban farsi', 'riazi omomi 2', 'mabani computer', 'moadelat difransiel', 'zaban takhasosi', 'kargah omomi', 'madar haye elektriki', 'moadelat', 'az fizik 2', 'amar o ehtemal', 'jabr khati', 'madar manteghi', 'memari computer', 'signals and systems', 'mohandesi narmafzar', 'system haye amel', 'ravesh haye pazhohesh'], 'Semester_Passed': ['Even', 'Odd', 'Even', 'Even', 'Odd', 'Odd', 'Odd', 'Even', 'Even', 'Odd', 'Odd', 'Odd', 'Even', 'Even', 'Even', 'Even', 'Odd', 'Odd', 'Odd', 'Odd', 'Even', 'Even', 'Odd', 'Odd', 'Even'], 'ECTS': [2, 3, 3, 3, 3, 2, 3, 1, 3, 3, 3, 3, 3, 1, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3], 'Specialized_or_General_or_Basic': ['General', 'General', 'Basic', 'Specialized', 'Specialized', 'General', 'General', 'General', 'General', 'General', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized', 'Specialized'], 'Instructor': ['Hajari', 'Salimi', 'Ahmadi', 'Mohammadi', 'Bidki', 'sajadi', 'Hajari', 'fotohi', 'Salimi', 'motlagh', 'ranjbar', 'motlagh', 'mahmoodi', 'ranjbar', 'mahmoodi', 'sotoodeh', 'safi nia', 'motlagh', 'joozi', 'bidki', 'ahmadi', 'mohammadi', 'ahmadi', 'ahmadi', 'ranjbar'], 'Total_ECTS_in_Semester': [14, 17, 20, 14, 20, 5, 5, 14, 14, 17, 17, 17, 20, 20, 20, 20, 16, 16, 16, 16, 14, 14, 20, 20, 20], 'Days_for_Final_Test': [2, 1, 1, 2, 0, 1, 0, 0, 2, 2, 2, 1, 4, 1, 0, 2, 0, 2, 2, 1, 0, 1, 2, 2, 2], 'Nth_Test_of_Semester': [3, 2, 3, 3, 1, 2, 1, 0, 3, 2, 3, 4, 2, 3, 1, 4, 1, 2, 3, 4, 1, 2, 2, 3, 3], 'Homework': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'], 'Quiz': ['No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'], 'Passed': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes'], 'Conditionally_Passed': ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No'], 'Grade': ['A', 'A', 'A', 'A', 'B', 'A', 'B', 'A', 'A', 'C', 'B', 'C', 'A', 'B', 'C', 'B', 'B', 'C', 'B', 'C', 'A', 'B', 'B', 'B', 'A'], 'num_Grade': ['19.83', '17.50', '17.10', '16', '12.50', '17.50', '15', '20', '19', '10', '12.94', '9', '20', '13', '9.9', '13.60', '15', '10', '15', '10', '16.20', '13.50', '15', '11.65', '19.33']}

# %%
# Convert num_Grade values to float
num_Grade_values = [float(value) for value in data['num_Grade']]

# Create a box plot for num_Grade
plt.figure(figsize=(8, 6))
plt.boxplot(num_Grade_values)
plt.title('Box Plot of num_Grade')
plt.ylabel('num_Grade')
plt.show()

# %%
# Extract numeric attributes
numeric_attributes = ['ECTS', 'Total_ECTS_in_Semester', 'Days_for_Final_Test', 'Nth_Test_of_Semester', 'num_Grade']

# Create scatter plots for pairs of numeric attributes
for i in range(len(numeric_attributes)):
    for j in range(i+1, len(numeric_attributes)):
        plt.figure(figsize=(8, 6))
        plt.scatter(data[numeric_attributes[i]], data[numeric_attributes[j]])
        plt.title(f'Scatter Plot of {numeric_attributes[i]} vs {numeric_attributes[j]}')
        plt.xlabel(numeric_attributes[i])
        plt.ylabel(numeric_attributes[j])
        plt.grid(True)
        plt.show()
