# %%
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import pickle

# %%
train_dir = 'dataset/train'
valid_dir = 'dataset/test'

# %%
batch_size = 8
target_size = (256, 256)  # Adjust the target size according to your requirements
color_mode = 'grayscale'
class_mode = 'binary'

train_data_generator = ImageDataGenerator(rescale=1.0 / 255)
valid_data_generator = ImageDataGenerator(rescale=1.0 / 255)

train_generator = train_data_generator.flow_from_directory(
    train_dir,
    target_size=target_size,
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode=class_mode
)

valid_generator = valid_data_generator.flow_from_directory(
    valid_dir,
    target_size=target_size,
    color_mode=color_mode,
    batch_size=batch_size,
    class_mode=class_mode
)
# Out:
# Found 3201 images belonging to 2 classes.
# Found 799 images belonging to 2 classes.

# %%
# Generate a random batch of images and labels
images, labels = next(train_generator)

# Display the images from the batch
num_images = images.shape[0]

for i in range(num_images):
   plt.imshow(images[i], cmap='gray')
   plt.show()

# %%
# each batch
print(images.shape)
# every image in each batch
print(train_generator.image_shape)
# Out:
# (8, 256, 256, 1)
# (256, 256, 1)

# %%
# Define the CNN model
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 1)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten the feature maps
model.add(layers.Flatten())

# Dense layers
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))  # Binary classification

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 32)      320
#
#  max_pooling2d_3 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 115200)            0
#
#  dense_2 (Dense)             (None, 128)               14745728
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 14838529 (56.60 MB)
# Trainable params: 14838529 (56.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_generator, steps_per_epoch = 401, epochs = 6,
            validation_data = valid_generator, validation_steps = 401, verbose = 1)
# Out:
# Epoch 1/6
# 401/401 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.5448WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 401 batches). You may need to use the repeat() function when building your dataset.
# 401/401 [==============================] - 226s 560ms/step - loss: 0.6887 - accuracy: 0.5448 - val_loss: 0.6774 - val_accuracy: 0.5807
# Epoch 2/6
# 401/401 [==============================] - 213s 531ms/step - loss: 0.6774 - accuracy: 0.5789
# Epoch 3/6
# 401/401 [==============================] - 209s 521ms/step - loss: 0.6746 - accuracy: 0.5904
# Epoch 4/6
# 401/401 [==============================] - 220s 550ms/step - loss: 0.6809 - accuracy: 0.5811
# Epoch 5/6
# 401/401 [==============================] - 250s 624ms/step - loss: 0.6640 - accuracy: 0.6051
# Epoch 6/6
# 401/401 [==============================] - 249s 622ms/step - loss: 0.6248 - accuracy: 0.6607

# %%
loss, accuracy = model.evaluate(valid_generator)

print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# 100/100 [==============================] - 14s 138ms/step - loss: 0.6479 - accuracy: 0.6408
# Test loss: 0.6478824019432068
# Test accuracy: 0.6408010125160217

# %%
# Save the trained model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
